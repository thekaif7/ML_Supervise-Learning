# %%
import mglearn
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
X , y = mglearn.datasets.make_forge()
#plot the data

mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
plt.legend(["Class 0", "Class 1"], loc=4)
plt.xlabel("First feature")
plt.ylabel("Second feature")
print("X.shape: {}".format(X.shape))
# Out:
# C:\Users\se7en\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:77: DeprecationWarning: Function make_blobs is deprecated; Please import make_blobs directly from scikit-learn
#   warnings.warn(msg, category=DeprecationWarning)
# X.shape: (26, 2)

# %%
mglearn.plots.plot_knn_classification(n_neighbors=1)
# Out:
# C:\Users\se7en\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:77: DeprecationWarning: Function make_blobs is deprecated; Please import make_blobs directly from scikit-learn
#   warnings.warn(msg, category=DeprecationWarning)

# %%
#generating train and test data
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X , y, random_state = 0)

# %%
#fit the data to algorithm
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#            weights='uniform')

# %%
#test the model 
print("test prediction : {}".format(knn.predict(X_test)))
# Out:
# test prediction : [1 0 1 0 1 0 0]

# %%
#test Accuracy
print(f"Test set accuracy: {round(knn.score(X_test,y_test),2)*100} % ")
# Out:
# Test set accuracy: 86.0 %

# %%
# Out:
#   File "<ipython-input-1-8f3b4776f102>", line 5
#     mglearn.discrete_scatter(X[:, 0], X[:, 1], y, ax=ax)    ax.set_title("{} neighbor(s)".format(n_neighbors))
#                                                              ^
# SyntaxError: invalid syntax
